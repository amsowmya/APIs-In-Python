# %%
import pandas as pd
import requests
import time

# %%
API_KEY = 'AIzaSyAlcNN3k60kr5TXw9tfWg6_FmE_GYSppdg'
CHANNEL_ID = 'UCYUjYU5FveRAscQ8V21w81A'

# %%
# # make api call
# response = requests.get('https://api.github.com').json()
# response

# %%
# https://developers.google.com/youtube/v3/docs/search/list
# url = 'https://www.googleapis.com/youtube/v3/search'

pageToken = "" 
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

response = requests.get(url).json()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'RlRmD3t4TRyjuwCNqJoRIvA-c4c',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 218, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '-3c7ZtDTtbRT8fufNldqBMXie_U',
#    'id': {'kind': 'youtube#video', 'videoId': 'cOSRUlTf7Rw'},
#    'snippet': {'publishedAt': '2022-11-25T11:40:02Z',
#     'channelId': 'UCYUjYU5FveRAscQ8V21w81A',
#     'title': 'Object Detection on the Web',
#     'description': 'Learn to run object detection in the browser. Not only that you will learn to create custom object detectors and run them on the web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cOSRUlTf7Rw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cOSRUlTf7Rw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cOSRUlTf7Rw/hqdefault.jpg',
# ...

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '-3c7ZtDTtbRT8fufNldqBMXie_U',
#  'id': {'kind': 'youtube#video', 'videoId': 'cOSRUlTf7Rw'},
#  'snippet': {'publishedAt': '2022-11-25T11:40:02Z',
#   'channelId': 'UCYUjYU5FveRAscQ8V21w81A',
#   'title': 'Object Detection on the Web',
#   'description': 'Learn to run object detection in the browser. Not only that you will learn to create custom object detectors and run them on the web ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cOSRUlTf7Rw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/cOSRUlTf7Rw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/cOSRUlTf7Rw/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': "Murtaza's Workshop - Robotics and AI",
#   'liveBroadcastContent': 'none',
#   'publishTime': '2022-11-25T11:40:02Z'}}

# %% [markdown]
# ## video_id = response['items'][0]['id']['videoId']

# %%
video_title = response['items'][0]['snippet']['title']
video_title = str(video_title).replace("&amp;", "")
video_title
# Out:
# 'Object Detection on the Web'

# %%
publish_time = response['items'][0]['snippet']['publishTime']
publish_time = str(publish_time).split('T')[0]
publish_time
# Out:
# '2022-11-25'

# %%
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;", "")
        publish_time = video['snippet']['publishTime']
        publish_time = str(publish_time).split('T')[0]
        
        print(video_id)
        print(video_title)
        print(publish_time)
# Out:
# cOSRUlTf7Rw
# Object Detection on the Web
# 2022-11-25
# P5eDRz0vFME
# Object Detection in the browser | Computer Vision Web Development
# 2022-11-25
# w2d4NG4Qbdg
# Customer Engagement using Computer Vision Web Development.
# 2022-11-24
# C5Qwr75cyzw
# Automated Shirt Size Measurement - Computer Vision Web Development
# 2022-11-24
# EM9fA0uJn6w
# Recyclable Waste Classifier using Opencv Python | Computer Vision
# 2022-10-16
# DnROHe3vBb4
# Join me at the Nvidia’s GTC 2022 and win a 3080 Ti
# 2022-09-19
# fdmrHb1hW6o
# Petoi Bittle - Robot Dog Compatible with Raspberry Pi
# 2022-09-04
# VcrBkUbdqbY
# Educational Kids Game using Computer Vision | OpenCV Python
# 2022-08-26
# wa2ARoUUdU8
# Easy Hand Sign Detection | American Sign Language ASL | Computer Vision
# 2022-07-04
# k2EahPgl0ho
# Rock Paper Scissor using Computer Vision | OpenCV Python
# 2022-06-26
# rKPzyBupcA4
# AI Typing Tutor using Opencv Python | Computer Vision
# 2022-05-15
# m-CHTkMW_ho
# ...

# %%
url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
response_video_stats = requests.get(url_video_stats).json()

response_video_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'XZiseuebJ6KRSpRRLplPTk47KUM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'VCUBO_U7ssbppQx5nWlqeAtNoo8',
#    'id': 'jzXZVFqEE2I',
#    'statistics': {'viewCount': '231675',
#     'likeCount': '3860',
#     'favoriteCount': '0',
#     'commentCount': '301'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
view_count = response_video_stats['items'][0]['statistics']['viewCount']
like_count = response_video_stats['items'][0]['statistics']['likeCount']
commentCount = response_video_stats['items'][0]['statistics']['commentCount']

print(view_count)
print(like_count)
print(commentCount)
# Out:
# 231675
# 3860
# 301

# %%
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;", "")
        publish_time = video['snippet']['publishTime']
        publish_time = str(publish_time).split('T')[0]
        
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
        response_video_stats = requests.get(url_video_stats).json()
        
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        commentCount = response_video_stats['items'][0]['statistics']['commentCount']

# %%
# build our dataframe
df = pd.DataFrame(columns=["video_id", "video_title", "publish_time", "view_count", "like_count", "commentCount"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, publish_time, view_count, like_count, commentCount]
# Index: []

# %%
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;", "")
        publish_time = video['snippet']['publishTime']
        publish_time = str(publish_time).split('T')[0]
        
        # collecting view, like, comment counts
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
        response_video_stats = requests.get(url_video_stats).json()
        
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        commentCount = response_video_stats['items'][0]['statistics']['commentCount']
        
        # save data in pandas df
        df = df.append({'video_id': video_id, 'video_title': video_title,
                        'publish_time': publish_time, 'view_count': view_count,
                        'like_count': like_count, 'commentCount': commentCount}, ignore_index=True)
# Out:
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_54532\339471469.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id': video_id, 'video_title': video_title,
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_54532\339471469.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id': video_id, 'video_title': video_title,
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_54532\339471469.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id': video_id, 'video_title': video_title,
# ...

# %%
df.head()
# Out:
#       video_id                                        video_title  \
# 0  cOSRUlTf7Rw                        Object Detection on the Web
# 1  P5eDRz0vFME  Object Detection in the browser | Computer Vis...
# 2  w2d4NG4Qbdg  Customer Engagement using Computer Vision Web ...
# 3  C5Qwr75cyzw  Automated Shirt Size Measurement - Computer Vi...
# 4  EM9fA0uJn6w  Recyclable Waste Classifier using Opencv Pytho...
#
#   publish_time view_count like_count commentCount
# 0   2022-11-25        392         16            0
# 1   2022-11-25       1067         62            5
# 2   2022-11-24       1543         39            5
# 3   2022-11-24       3964         95            5
# 4   2022-10-16       9374        287           29

# %%
def get_video_details(video_id):
    
    # collecting view, like, comment counts
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    commentCount = response_video_stats['items'][0]['statistics']['commentCount']
    
    return view_count, like_count, commentCount

# %%
def get_videos(df):
    pageToken = "" 
    url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

    response = requests.get(url).json()
    time.sleep(1)

    for video in response['items']:
        if video['id']['kind'] == "youtube#video":
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            video_title = str(video_title).replace("&amp;", "")
            publish_time = video['snippet']['publishTime']
            publish_time = str(publish_time).split('T')[0]

            view_count, like_count, commentCount = get_video_details(video_id)

            # save data in pandas df
            df = df.append({'video_id': video_id, 'video_title': video_title,
                            'publish_time': publish_time, 'view_count': view_count,
                            'like_count': like_count, 'commentCount': commentCount}, ignore_index=True)
            
    return df

# %%
# main

# build our dataframe
df = pd.DataFrame(columns = ["video_id", "video_title", "publish_time", "view_count", "like_count", "commentCount"])

df = get_videos(df)
# Out:
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_54532\2697290121.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id': video_id, 'video_title': video_title,
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_54532\2697290121.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id': video_id, 'video_title': video_title,
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_54532\2697290121.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id': video_id, 'video_title': video_title,
# ...

# %%
df.head()
# Out:
#       video_id                                        video_title  \
# 0  P5eDRz0vFME  Object Detection in the browser | Computer Vis...
# 1  w2d4NG4Qbdg  Customer Engagement using Computer Vision Web ...
# 2  C5Qwr75cyzw  Automated Shirt Size Measurement - Computer Vi...
# 3  EM9fA0uJn6w  Recyclable Waste Classifier using Opencv Pytho...
# 4  DnROHe3vBb4  Join me at the Nvidia’s GTC 2022 and win a 308...
#
#   publish_time view_count like_count commentCount
# 0   2022-11-25       1080         62            5
# 1   2022-11-24       1550         39            5
# 2   2022-11-24       3973         95            5
# 3   2022-10-16       9374        287           29
# 4   2022-09-19       3323        113            4
